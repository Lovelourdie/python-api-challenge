# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 619

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url ="http://api.openweathermap.org/data/2.5/weather?"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+f"q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat=city_weather['coord']['lat']
        city_lng=city_weather['coord']['lon']
        
        city_max_temp =city_weather['main']['temp']
        city_humidity =city_weather['main']['humidity']
        city_clouds =city_weather['clouds']['all']
        city_wind =city_weather['wind']['speed']
        city_country =city_weather['sys']['country']
        city_date =city_weather['timezone']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
    
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | papatowai
# Processing Record 2 of Set 1 | tralee
# Processing Record 3 of Set 1 | conception bay south
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | waitangi
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | mejit
# Processing Record 8 of Set 1 | zamora
# Processing Record 9 of Set 1 | igarka
# Processing Record 10 of Set 1 | weno
# Processing Record 11 of Set 1 | puerto penasco
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | kenai
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | grytviken
# Processing Record 18 of Set 1 | grand falls-windsor
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | at-bashi
# Processing Record 21 of Set 1 | bilibino
# Processing Record 22 of Set 1 | arkhangel'sk
# Processing Record 23 of Set 1 | khandud
# Processing Record 24 of Set 1 | yuanping
# Processing Record 25 of Set 1 | aasiaat
# Processing Record 26 of Set 1 | isle of lewis
# City not found. Skipping...
# Processing Record 27 of Set 1 | valdivia
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | eureka
# Processing Record 32 of Set 1 | port-aux-francais
# Processing Record 33 of Set 1 | nemuro
# Processing Record 34 of Set 1 | jaunjelgava
# Processing Record 35 of Set 1 | yeppoon
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | iskateley
# Processing Record 38 of Set 1 | kamenka
# Processing Record 39 of Set 1 | toamasina
# Processing Record 40 of Set 1 | kiruna
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | pathein
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | utrik
# Processing Record 45 of Set 1 | melekeok village
# Processing Record 46 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 1 | okha
# Processing Record 48 of Set 1 | invercargill
# Processing Record 49 of Set 1 | mukah
# City not found. Skipping...
# Processing Record 50 of Set 1 | coracora
# Processing Record 0 of Set 2 | san pedro pochutla
# Processing Record 1 of Set 2 | mount gambier
# Processing Record 2 of Set 2 | pemangkat
# Processing Record 3 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 2 | lakshmipur
# Processing Record 5 of Set 2 | mogoytuy
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | petauke
# Processing Record 9 of Set 2 | okhotsk
# Processing Record 10 of Set 2 | puerto deseado
# Processing Record 11 of Set 2 | sterling
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | atafu village
# Processing Record 15 of Set 2 | yugorsk
# Processing Record 16 of Set 2 | paradip garh
# Processing Record 17 of Set 2 | walvis bay
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | verkhnevilyuysk
# Processing Record 49 of Set 3 | nishinoomote
# Processing Record 0 of Set 4 | zemio
# Processing Record 1 of Set 4 | alofi
# Processing Record 2 of Set 4 | aykhal
# Processing Record 3 of Set 4 | ngaoundere
# Processing Record 4 of Set 4 | yermentau
# Processing Record 5 of Set 4 | sittwe
# Processing Record 6 of Set 4 | chulakkurgan
# Processing Record 7 of Set 4 | gaalkacyo
# Processing Record 8 of Set 4 | acarau
# Processing Record 9 of Set 4 | st. john's
# Processing Record 10 of Set 4 | ust-nera
# Processing Record 11 of Set 4 | mount pearl
# Processing Record 12 of Set 4 | kashmar
# Processing Record 13 of Set 4 | mumford
# Processing Record 14 of Set 4 | christchurch
# Processing Record 15 of Set 4 | queenstown
# Processing Record 16 of Set 4 | tual
# Processing Record 17 of Set 4 | vila franca do campo
# Processing Record 18 of Set 4 | millville
# Processing Record 19 of Set 4 | nagqu
# Processing Record 20 of Set 4 | sur
# Processing Record 21 of Set 4 | quelimane
# Processing Record 22 of Set 4 | anloga
# Processing Record 23 of Set 4 | muynoq
# Processing Record 24 of Set 4 | rabo de peixe
# Processing Record 25 of Set 4 | botelhos
# Processing Record 26 of Set 4 | mahdia
# Processing Record 27 of Set 4 | chonchi
# Processing Record 28 of Set 4 | qaqortoq
# Processing Record 29 of Set 4 | gebeit
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | susuman
# Processing Record 32 of Set 4 | huaral
# Processing Record 33 of Set 4 | north battleford
# Processing Record 34 of Set 4 | darovskoy
# Processing Record 35 of Set 4 | covington
# Processing Record 36 of Set 4 | cidreira
# Processing Record 37 of Set 4 | kourou
# Processing Record 38 of Set 4 | sao joao da barra
# Processing Record 39 of Set 4 | yemetsk
# Processing Record 40 of Set 4 | port mathurin
# Processing Record 41 of Set 4 | road town
# Processing Record 42 of Set 4 | sabang
# Processing Record 43 of Set 4 | chernyshevskiy
# Processing Record 44 of Set 4 | kegen
# Processing Record 45 of Set 4 | chibougamau
# Processing Record 46 of Set 4 | broome
# Processing Record 47 of Set 4 | kodoli
# Processing Record 48 of Set 4 | zhanga buqtyrma
# Processing Record 49 of Set 4 | masindi port
# Processing Record 0 of Set 5 | albertina
# Processing Record 1 of Set 5 | gagarin
# Processing Record 2 of Set 5 | crane
# Processing Record 3 of Set 5 | la sarre
# Processing Record 4 of Set 5 | imbituba
# Processing Record 5 of Set 5 | hoemul-li
# Processing Record 6 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 7 of Set 5 | kamaishi
# Processing Record 8 of Set 5 | la'ie
# Processing Record 9 of Set 5 | san antonio oeste
# Processing Record 10 of Set 5 | severo-yeniseyskiy
# Processing Record 11 of Set 5 | nadi
# Processing Record 12 of Set 5 | volya
# Processing Record 13 of Set 5 | avarua
# Processing Record 14 of Set 5 | khandyga
# Processing Record 15 of Set 5 | urangan
# Processing Record 16 of Set 5 | artem
# Processing Record 17 of Set 5 | camana
# Processing Record 18 of Set 5 | mbandaka
# Processing Record 19 of Set 5 | thompson
# Processing Record 20 of Set 5 | terrigal
# Processing Record 21 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 22 of Set 5 | puerto baquerizo moreno
# Processing Record 23 of Set 5 | canal winchester
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | kachkanar
# Processing Record 26 of Set 5 | santa rosa
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | mocimboa
# Processing Record 29 of Set 5 | westport
# Processing Record 30 of Set 5 | alpine
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | amahai
# Processing Record 33 of Set 5 | black point
# Processing Record 34 of Set 5 | rongelap
# Processing Record 35 of Set 5 | xiaoweizhai
# Processing Record 36 of Set 5 | castillos
# Processing Record 37 of Set 5 | whitehorse
# Processing Record 38 of Set 5 | novodvinsk
# Processing Record 39 of Set 5 | ujae
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | haiku-pauwela
# Processing Record 42 of Set 5 | selibaby
# Processing Record 43 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 44 of Set 5 | usogorsk
# Processing Record 45 of Set 5 | kigoma
# Processing Record 46 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 47 of Set 5 | hancheng
# Processing Record 48 of Set 5 | labrador city
# Processing Record 49 of Set 5 | spearfish
# Processing Record 0 of Set 6 | awjilah
# Processing Record 1 of Set 6 | mahina
# Processing Record 2 of Set 6 | saint-francois
# Processing Record 3 of Set 6 | bodo
# Processing Record 4 of Set 6 | port augusta
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | nuku'alofa
# Processing Record 7 of Set 6 | yulinshi
# Processing Record 8 of Set 6 | moura
# Processing Record 9 of Set 6 | chabahar
# Processing Record 10 of Set 6 | pestovo
# Processing Record 11 of Set 6 | kristiansund
# Processing Record 12 of Set 6 | manakara
# Processing Record 13 of Set 6 | langepas
# Processing Record 14 of Set 6 | salekhard
# Processing Record 15 of Set 6 | sarh
# Processing Record 16 of Set 6 | fort st. john
# Processing Record 17 of Set 6 | sao joao de pirabas
# Processing Record 18 of Set 6 | mwinilunga
# Processing Record 19 of Set 6 | malango
# Processing Record 20 of Set 6 | conde
# Processing Record 21 of Set 6 | kibakwe
# Processing Record 22 of Set 6 | olhao
# Processing Record 23 of Set 6 | enriquillo
# Processing Record 24 of Set 6 | hsinchu
# Processing Record 25 of Set 6 | boa vista
# Processing Record 26 of Set 6 | plastun
# Processing Record 27 of Set 6 | kralendijk
# Processing Record 28 of Set 6 | acapulco de juarez
# Processing Record 29 of Set 6 | marica
# Processing Record 30 of Set 6 | saipan
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 6 | cao bang
# Processing Record 34 of Set 6 | fortaleza
# Processing Record 35 of Set 6 | villa gesell
# Processing Record 36 of Set 6 | erenhot
# Processing Record 37 of Set 6 | vel'sk
# Processing Record 38 of Set 6 | brookings
# Processing Record 39 of Set 6 | ghat
# Processing Record 40 of Set 6 | new norfolk
# Processing Record 41 of Set 6 | khilok
# Processing Record 42 of Set 6 | ain fakroun
# Processing Record 43 of Set 6 | flying fish cove
# Processing Record 44 of Set 6 | chincha alta
# Processing Record 45 of Set 6 | kansas city
# Processing Record 46 of Set 6 | la paz
# Processing Record 47 of Set 6 | pauini
# Processing Record 48 of Set 6 | nogliki
# Processing Record 49 of Set 6 | solok
# Processing Record 0 of Set 7 | uturoa
# Processing Record 1 of Set 7 | akureyri
# Processing Record 2 of Set 7 | luau
# Processing Record 3 of Set 7 | rondonopolis
# Processing Record 4 of Set 7 | stanley
# Processing Record 5 of Set 7 | lorengau
# Processing Record 6 of Set 7 | champerico
# Processing Record 7 of Set 7 | keflavik
# Processing Record 8 of Set 7 | rio tuba
# Processing Record 9 of Set 7 | megion
# Processing Record 10 of Set 7 | kolonia town
# Processing Record 11 of Set 7 | yako
# Processing Record 12 of Set 7 | bageshwar
# Processing Record 13 of Set 7 | newman
# Processing Record 14 of Set 7 | astrea
# Processing Record 15 of Set 7 | zetea
# Processing Record 16 of Set 7 | tebessa
# Processing Record 17 of Set 7 | oyama
# Processing Record 18 of Set 7 | ordynskoye
# Processing Record 19 of Set 7 | taltal
# Processing Record 20 of Set 7 | mount darwin
# Processing Record 21 of Set 7 | lompoc
# Processing Record 22 of Set 7 | plouzane
# Processing Record 23 of Set 7 | yinchuan
# Processing Record 24 of Set 7 | saint-leu
# Processing Record 25 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 26 of Set 7 | prince rupert
# Processing Record 27 of Set 7 | tsiombe
# Processing Record 28 of Set 7 | simanggang
# Processing Record 29 of Set 7 | nar'yan-mar
# Processing Record 30 of Set 7 | la ronge
# Processing Record 31 of Set 7 | wenchang
# Processing Record 32 of Set 7 | howrah
# Processing Record 33 of Set 7 | rivne
# Processing Record 34 of Set 7 | ephraim
# Processing Record 35 of Set 7 | berezovyy
# Processing Record 36 of Set 7 | bikenibeu village
# Processing Record 37 of Set 7 | aguas vermelhas
# Processing Record 38 of Set 7 | moranbah
# Processing Record 39 of Set 7 | carazinho
# Processing Record 40 of Set 7 | tabou
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | vallenar
# Processing Record 43 of Set 7 | mangrol
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | san jose de jachal
# Processing Record 46 of Set 7 | at taj
# Processing Record 47 of Set 7 | sisimiut
# Processing Record 48 of Set 7 | sitka
# Processing Record 49 of Set 7 | aldama
# Processing Record 0 of Set 8 | fort bragg
# Processing Record 1 of Set 8 | kiunga
# Processing Record 2 of Set 8 | messaad
# Processing Record 3 of Set 8 | qal'at bishah
# City not found. Skipping...
# Processing Record 4 of Set 8 | kapa'a
# Processing Record 5 of Set 8 | sal'sk
# Processing Record 6 of Set 8 | bandarbeyla
# Processing Record 7 of Set 8 | broken hill
# Processing Record 8 of Set 8 | san antonio de pale
# Processing Record 9 of Set 8 | polovinnoye
# Processing Record 10 of Set 8 | papao
# Processing Record 11 of Set 8 | ulladulla
# Processing Record 12 of Set 8 | lensk
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | argostolion
# Processing Record 15 of Set 8 | urengoy
# Processing Record 16 of Set 8 | de aar
# Processing Record 17 of Set 8 | takikawa
# Processing Record 18 of Set 8 | hirara
# Processing Record 19 of Set 8 | quang ngai
# Processing Record 20 of Set 8 | date
# Processing Record 21 of Set 8 | dzhambeyty
# Processing Record 46 of Set 9 | tha khanon
# Processing Record 47 of Set 9 | villamontes
# Processing Record 48 of Set 9 | beyneu
# Processing Record 49 of Set 9 | yanam
# Processing Record 0 of Set 10 | sharifabad
# Processing Record 1 of Set 10 | tofol
# Processing Record 2 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 3 of Set 10 | pimentel
# Processing Record 4 of Set 10 | vernon
# Processing Record 5 of Set 10 | mahudha
# Processing Record 6 of Set 10 | sao vicente
# Processing Record 7 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 10 | akrehamn
# Processing Record 9 of Set 10 | nikolayevsk-on-amure
# Processing Record 10 of Set 10 | terra santa
# Processing Record 11 of Set 10 | egilsstadir
# Processing Record 12 of Set 10 | klyuchi
# Processing Record 13 of Set 10 | huron
# Processing Record 14 of Set 10 | arraial do cabo
# Processing Record 15 of Set 10 | manfalut
# Processing Record 16 of Set 10 | plettenberg bay
# Processing Record 17 of Set 10 | hasaki
# Processing Record 18 of Set 10 | benghazi
# Processing Record 19 of Set 10 | isla del bosque
# Processing Record 20 of Set 10 | tazacorte
# Processing Record 21 of Set 10 | cestos city
# Processing Record 22 of Set 10 | piti village
# Processing Record 23 of Set 10 | kargopol'
# Processing Record 24 of Set 10 | ribeira brava
# Processing Record 25 of Set 10 | dakhla
# Processing Record 26 of Set 10 | tefe
# Processing Record 27 of Set 10 | pisco
# Processing Record 28 of Set 10 | college
# Processing Record 29 of Set 10 | palapag
# Processing Record 30 of Set 10 | hermanus
# Processing Record 31 of Set 10 | thinadhoo
# Processing Record 32 of Set 10 | tafuna
# Processing Record 33 of Set 10 | kushiro
# Processing Record 34 of Set 10 | richards bay
# Processing Record 35 of Set 10 | terbanggi besar
# Processing Record 36 of Set 10 | port hedland
# Processing Record 37 of Set 10 | kilindoni
# Processing Record 38 of Set 10 | mili
# Processing Record 39 of Set 10 | khargone
# Processing Record 40 of Set 10 | daru
# Processing Record 41 of Set 10 | ola
# Processing Record 42 of Set 10 | prieska
# Processing Record 43 of Set 10 | saurimo
# Processing Record 44 of Set 10 | buka
# Processing Record 45 of Set 10 | joal-fadiout
# Processing Record 46 of Set 10 | ipora
# Processing Record 47 of Set 10 | dange
# Processing Record 48 of Set 10 | mermoz boabab
# Processing Record 49 of Set 10 | moratuwa
# Processing Record 0 of Set 11 | tauranga
# Processing Record 1 of Set 11 | san agustin de valle fertil
# Processing Record 2 of Set 11 | jonquiere
# Processing Record 3 of Set 11 | praia da vitoria
# Processing Record 4 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 5 of Set 11 | sandnessjoen
# Processing Record 6 of Set 11 | jiangyou
# Processing Record 7 of Set 11 | nadym
# Processing Record 8 of Set 11 | khanpur
# Processing Record 9 of Set 11 | tionk essil
# Processing Record 10 of Set 11 | ulsteinvik
# Processing Record 11 of Set 11 | centerville
# Processing Record 12 of Set 11 | afif
# Processing Record 13 of Set 11 | jindabyne
# Processing Record 14 of Set 11 | saint-denis
# Processing Record 15 of Set 11 | troitsko-pechorsk
# Processing Record 16 of Set 11 | chui
# Processing Record 17 of Set 11 | hilo
# Processing Record 18 of Set 11 | dhromolaxia
# Processing Record 19 of Set 11 | ladnun
# Processing Record 20 of Set 11 | kingscliff
# Processing Record 21 of Set 11 | dem'yanovo
# Processing Record 22 of Set 11 | znamensk
# Processing Record 23 of Set 11 | mar del plata
# Processing Record 24 of Set 11 | tashtagol
# Processing Record 25 of Set 11 | laibin
# Processing Record 26 of Set 11 | constitucion
# Processing Record 27 of Set 11 | itapirapua
# Processing Record 28 of Set 11 | lingyuan
# Processing Record 29 of Set 11 | canto do buriti
# Processing Record 30 of Set 11 | puerto carreno
# Processing Record 31 of Set 11 | loanda
# Processing Record 32 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 33 of Set 11 | khanty-mansiysk
# Processing Record 34 of Set 11 | rosignano solvay-castiglioncello
# City not found. Skipping...
# Processing Record 35 of Set 11 | tindouf
# Processing Record 36 of Set 11 | damboa
# Processing Record 37 of Set 11 | aketi
# Processing Record 38 of Set 11 | robore
# Processing Record 39 of Set 11 | levuka
# Processing Record 40 of Set 11 | kunyang
# Processing Record 41 of Set 11 | alamogordo
# Processing Record 42 of Set 11 | kayangel
# Processing Record 43 of Set 11 | carutapera
# Processing Record 44 of Set 11 | fortuna
# Processing Record 45 of Set 11 | boma
# Processing Record 46 of Set 11 | leticia
# Processing Record 47 of Set 11 | luwuk
# Processing Record 48 of Set 11 | zhalantun
# Processing Record 49 of Set 11 | am djarass
# City not found. Skipping...
# Processing Record 0 of Set 12 | bafq
# Processing Record 1 of Set 12 | grand-bassam
# Processing Record 2 of Set 12 | onega
# Processing Record 3 of Set 12 | madanapalle
# Processing Record 4 of Set 12 | krosno odrzanskie
# Processing Record 5 of Set 12 | caister-on-sea
# Processing Record 6 of Set 12 | punta alta
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | mount isa
# Processing Record 9 of Set 12 | baise city
# Processing Record 10 of Set 12 | livingston
# Processing Record 11 of Set 12 | fuyu
# Processing Record 12 of Set 12 | mcalester
# Processing Record 13 of Set 12 | pont rouge
# Processing Record 14 of Set 12 | noosa heads
# Processing Record 15 of Set 12 | geraldton
# Processing Record 16 of Set 12 | zouerate
# Processing Record 17 of Set 12 | kelso
# Processing Record 18 of Set 12 | weiser
# Processing Record 19 of Set 12 | moyynkum
# Processing Record 20 of Set 12 | san sebastian de la gomera
# Processing Record 21 of Set 12 | cold lake
# Processing Record 22 of Set 12 | dodola
# Processing Record 23 of Set 12 | guiuan
# Processing Record 24 of Set 12 | norrtalje
# Processing Record 25 of Set 12 | umm kaddadah
# Processing Record 26 of Set 12 | undurkhaan
# Processing Record 27 of Set 12 | carbonear
# Processing Record 28 of Set 12 | orcopampa
# Processing Record 29 of Set 12 | pechora
# Processing Record 30 of Set 12 | tayshet
# Processing Record 31 of Set 12 | torre del mar
# Processing Record 32 of Set 12 | vila velha
# Processing Record 33 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 34 of Set 12 | kloulklubed
# Processing Record 35 of Set 12 | antonio enes
# Processing Record 36 of Set 12 | zykovo
# Processing Record 37 of Set 12 | hamhung
# Processing Record 38 of Set 12 | greenland
# Processing Record 39 of Set 12 | purpe
# Processing Record 40 of Set 12 | laguna
# Processing Record 41 of Set 12 | nacozari de garcia
# Processing Record 42 of Set 12 | portland
# Processing Record 43 of Set 12 | dengi
# Processing Record 44 of Set 12 | omdurman
# Processing Record 45 of Set 12 | lembar
# City not found. Skipping...
# Processing Record 46 of Set 12 | abu 'arish
# City not found. Skipping...
# Processing Record 47 of Set 12 | waingapu
# Processing Record 48 of Set 12 | kalemie
# Processing Record 49 of Set 12 | bismarck
# Processing Record 0 of Set 13 | desnogorsk
# Processing Record 1 of Set 13 | zalingei
# Processing Record 2 of Set 13 | kodinsk
# Processing Record 3 of Set 13 | ndjole
# Processing Record 4 of Set 13 | beolgyo
# Processing Record 5 of Set 13 | tondano
# Processing Record 6 of Set 13 | inda silase
# Processing Record 7 of Set 13 | zaozersk
# Processing Record 8 of Set 13 | okahao
# Processing Record 9 of Set 13 | shillong
# Processing Record 10 of Set 13 | tobelo
# Processing Record 11 of Set 13 | obo
# Processing Record 12 of Set 13 | kapuskasing
# Processing Record 13 of Set 13 | villa de arista
# Processing Record 14 of Set 13 | urucui
# Processing Record 15 of Set 13 | zhuanghe
# Processing Record 16 of Set 13 | miranda
# Processing Record 17 of Set 13 | al kiremit al 'arakiyyin
# City not found. Skipping...
# Processing Record 18 of Set 13 | whakatane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df =pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             papatowai -46.5619  169.4708      6.07        83         100
# 1                tralee  52.2704   -9.7026      9.73        97          47
# 2  conception bay south  47.4999  -52.9981      1.69        96          40
# 3                albany  42.6001  -73.9662     15.09        67          94
# 4              waitangi -43.9535 -176.5597     13.23        78          34
#
#    Wind Speed Country   Date
# 0        4.13      NZ  43200
# 1        1.81      IE   3600
# 2        3.00      CA  -9000
# 3        1.92      US -14400
# 4        1.79      NZ  45900

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   papatowai -46.5619  169.4708      6.07        83
# 1                      tralee  52.2704   -9.7026      9.73        97
# 2        conception bay south  47.4999  -52.9981      1.69        96
# 3                      albany  42.6001  -73.9662     15.09        67
# 4                    waitangi -43.9535 -176.5597     13.23        78
#
#          Cloudiness  Wind Speed Country   Date
# City_ID
# 0               100        4.13      NZ  43200
# 1                47        1.81      IE   3600
# 2                40        3.00      CA  -9000
# 3                94        1.92      US -14400
# 4                34        1.79      NZ  45900

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
latitudes = [30, 35, 40, 45, 50]
temperatures = [20, 25, 30, 27, 22]


# Incorporate the other graph properties
# YOUR CODE HERE
marker_size = 100
xlim = (25, 55)
ylim = (15, 35)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(latitudes, temperatures, color='blue', alpha=0.5, s=marker_size)
plt.title('latitudes vs. temperatures')
plt.xlim(xlim)
plt.ylim(ylim)
plt.xlabel('latitudes')
plt.ylabel('temperatures (°C)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
import matplotlib.pyplot as plt

# Incorporate the other graph properties
# YOUR CODE HERE show the code
latitude = [30, 35, 40, 45, 50]
humidity = [60, 65, 70, 75, 80]

# Create scatter plot
plt.scatter(latitude, humidity)

# Add labels and title
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')

# Incorporate the other graph properties
# YOUR CODE HERE
marker_color = 'blue'
marker_size = 100
marker_style = '5'  # '4' for circle marker, '^' for triangle marker, etc.
alpha_value = 0.10   # Opacity of markers
xlim = (25, 55)
ylim = (55, 85)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']

# Incorporate the other graph properties
plt.scatter(latitude, cloudiness, edgecolors="black")
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Save the figure
plt.savefig("output_data/Fig3.png")
plt.grid()
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']

# Incorporate the other graph properties
plt.scatter(latitude, wind_speed, edgecolors="black")
plt.title('City Latitude vs. Wind Speed (2022-10-18)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Save the figure
plt.savefig("output_data/Fig4.png")
plt.grid()
# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

def plot_linear_regression(x_values, y_values, xlabel, ylabel, coordinates):
   
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
   
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,coordinates,fontsize=15,color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
   
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                      tralee  52.2704   -9.7026      9.73        97
# 2        conception bay south  47.4999  -52.9981      1.69        96
# 3                      albany  42.6001  -73.9662     15.09        67
# 6                       mejit  10.2753  170.8646     27.58        79
# 8                      igarka  67.4667   86.5833     -6.10        86
#
#          Cloudiness  Wind Speed Country   Date
# City_ID
# 1                47        1.81      IE   3600
# 2                40        3.00      CA  -9000
# 3                94        1.92      US -14400
# 6               100        8.56      MH  43200
# 8                98        3.58      RU  25200

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          papatowai -46.5619  169.4708      6.07        83
# 4                           waitangi -43.9535 -176.5597     13.23        78
# 5        edinburgh of the seven seas -37.0676  -12.3116     16.35        88
# 7                             zamora  -4.0692  -78.9567     20.37        99
# 11                         adamstown -25.0660 -130.1015     22.42        74
#
#          Cloudiness  Wind Speed Country   Date
# City_ID
# 0               100        4.13      NZ  43200
# 4                34        1.79      NZ  45900
# 5                98       12.24      SH      0
# 7                95        0.38      EC -18000
# 11               31       10.39      PN -28800

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          papatowai -46.5619  169.4708      6.07        83
# 4                           waitangi -43.9535 -176.5597     13.23        78
# 5        edinburgh of the seven seas -37.0676  -12.3116     16.35        88
# 7                             zamora  -4.0692  -78.9567     20.37        99
# 11                         adamstown -25.0660 -130.1015     22.42        74
#
#          Cloudiness  Wind Speed Country   Date
# City_ID
# 0               100        4.13      NZ  43200
# 4                34        1.79      NZ  45900
# 5                98       12.24      SH      0
# 7                95        0.38      EC -18000
# 11               31       10.39      PN -28800

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temp', (-20,5))
# Out:
# The r-squared is: 0.574293894741048

# %%
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temp', (10, 10))
# Out:
# The r-squared is: 0.7038290054805317

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity', (40,40))
# Out:
# The r-squared is: 0.0017254929074226487

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity', (-30,60))
# Out:
# The r-squared is: 0.040083257396973236

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness', (40,55))
# Out:
# The r-squared is: 0.011445356214635206

# %%
# southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness', (-30,40))
# Out:
# The r-squared is: 0.015948352444174023

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed', (40,3))
# Out:
# The r-squared is: 6.174833077353482e-07

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed', (-30,5))
# Out:
# The r-squared is: 0.012143201795901924

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
